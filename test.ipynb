# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjuadhikari14/coreplotting/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
categories=["a","b","c","d"]
values=[5,10,15,20]

# creating vertical bar graph

plt.bar(categories, values,color='red')
plt.title("Vertical Bar graph")
plt.xlabel("categories")
plt.ylabel("values")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Simple data
Data = {
    'days': ["sunday", "monday", "Tuesday", "wednesday", "thursday", "friday", "saturday"],
    'sales': [100, 150, 200, 250, 300, 350, 400],
    'return': [2, 4, 6, 8, 9, 0, 1],
    'loss': [5, 7, 9, 10, 2, 4, 7]
}

df = pd.DataFrame(Data)

# %%
plt.figure(figsize=(3,5))
plt.plot(df['days'], df['sales'], label='sales')
plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Sales Over the Week")
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.legend()
plt.tight_layout()       # Adjusts layout to prevent label cutoff
plt.show()

# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=4,random_state=42)

# Plot the generated data
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.title("Generated Blobs Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Simple data
Data = {
    'days': ["sunday", "monday", "Tuesday", "wednesday", "thursday", "friday", "saturday"],
    'sales': [100, 150, 200, 250, 300, 350, 400],
    'return': [2, 4, 6, 8, 9, 0, 1],
    'loss': [5, 7, 9, 10, 2, 4, 7]
}

df = pd.DataFrame(Data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   days    7 non-null      object
#  1   sales   7 non-null      int64
#  2   return  7 non-null      int64
#  3   loss    7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 356.0+ bytes

# %%
df.drop('days',axis=1,inplace=True)
df.head()
corr = df.corr()
# Plot heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Title
plt.title("Correlation Heatmap")
# Show plot
plt.show()
